# %% [markdown]
# # December 17, 2021
#
# Examine trajectory from locally-run simulation of an asymmetric trimer with $c=0.25$.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append('/Users/jfung/code/brownian_ot/')
import brownian_ot
from brownian_ot.analysis import expand_trajectory

# %%
traj = expand_trajectory(np.load('asym_trimer_c025_traj.npy'))

# %%
traj[0]
# Out:
# array([0.e+00, 0.e+00, 2.e-07, 1.e+00, 0.e+00, 0.e+00, 0.e+00, 1.e+00,
#        0.e+00, 0.e+00, 0.e+00, 1.e+00])

# %%
plt.plot(traj[:,0])
plt.plot(traj[:,1])

# %%
plt.plot(traj[:,2])

# %% [markdown]
# Looks like the particle escaped...

# %%
plt.plot(traj[:,3])
plt.plot(traj[:,4])
plt.plot(traj[:,5])

# %%
plt.plot(traj[:,6])
plt.plot(traj[:,7])
plt.plot(traj[:,8])

# %%
plt.plot(traj[:,9])
plt.plot(traj[:,10])
plt.plot(traj[:,11])

# %% [markdown]
# Clearly, something funky happened here. Maybe it's worth trying it on Expanse at 20 mW power, starting at $z = 0.4$ micron, $x = 0.5$ micron.
